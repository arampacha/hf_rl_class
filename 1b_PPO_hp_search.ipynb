# %% [markdown]
# <a href="https://colab.research.google.com/github/arampacha/hf_rl_class/blob/main/1b_PPO_hp_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys
if 'google.colab' in sys.modules:
    # !apt install python-opengl ffmpeg xvfb
    # !pip install pyvirtualdisplay
    # !pip install gym[box2d] stable-baselines3[extra] huggingface_sb3 pyglet
    # !pip install ale-py==0.7.4 # To overcome an issue with gym (https://github.com/DLR-RM/stable-baselines3/issues/875)
    # !pip install wandb

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gym

from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor

import wandb
from wandb.integration.sb3 import WandbCallback

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: arampacha. Use `wandb login --relogin` to force relogin
# True

# %%
# notebook_login()
# !git config --global credential.helper store

# %%
sweep_config = {
    "project": "hf-deep-lr-class",
    "entity": "arampacha",
    "name" : "LunarLander-v2",
    "method" : "grid",
    "parameters": {
        "lr": {
            "values": [1e-4, 5e-4, 1e-3]
        },
        "decay": {
            "values": [False]
        },
        "batch_size": {"values": [128]},
        "target_kl": {"values":[None, .005, .01]},
        "ent_coef": {"values":[0, 0.01]}
    }
}

# %%
from IPython.display import clear_output

def train():

    clear_output()
    with wandb.init(sync_tensorboard=True) as run:
        ENV_NAME = 'LunarLander-v2'
        cfg = run.config

        env = make_vec_env(ENV_NAME, n_envs=16)
        def linear_decay_sched(pct):
            return pct*cfg.lr
        lr = linear_decay_sched if cfg.decay else cfg.lr

        model = PPO(
            "MlpPolicy", 
            env,
            learning_rate=lr, 
            verbose=1, 
            tensorboard_log=f"runs/{run.id}",
            batch_size=cfg.batch_size,
            target_kl=cfg.target_kl,
            ent_coef=cfg.ent_coef
        )
        model_name = f"{ENV_NAME}-ppo"
        model.learn(
            total_timesteps=int(1e6),
            callback=WandbCallback(
                gradient_save_freq=100,
                model_save_path=model_name,
                verbose=2,
            ),
        )
        eval_env = DummyVecEnv([lambda: Monitor(gym.make(ENV_NAME))])
        mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
        wandb.log({"eval_reward_mean":mean_reward, "eval_reward_std":std_reward})

# %%
sweep_id = wandb.sweep(sweep_config, entity="arampacha", project="hf-deep-rl-class")
wandb.agent(sweep_id, function=train)
# Out:
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220509_220356-w6sb18k2</code>
# Syncing run <strong><a href="https://wandb.ai/arampacha/hf-deep-rl-class/runs/w6sb18k2" target="_blank">blooming-sweep-2</a></strong> to <a href="https://wandb.ai/arampacha/hf-deep-rl-class" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/arampacha/hf-deep-rl-class/sweeps/2hronjr9" target="_blank">https://wandb.ai/arampacha/hf-deep-rl-class/sweeps/2hronjr9</a>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Logging to runs/w6sb18k2/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.7     |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    fps             | 3117     |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 32768    |
# ---------------------------------
# Early stopping at step 9 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.2        |
# |    ep_rew_mean          | -158        |
# | time/                   |             |
# |    fps                  | 2210        |
# |    iterations           | 2           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005927865 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00601    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 539         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.2         |
# |    ep_rew_mean          | -129         |
# | time/                   |              |
# |    fps                  | 2244         |
# |    iterations           | 3            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0051380238 |
# |    clip_fraction        | 0.00821      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000599    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 619          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 872          |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | -130         |
# | time/                   |              |
# |    fps                  | 2332         |
# |    iterations           | 4            |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0046395003 |
# |    clip_fraction        | 0.00167      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00345     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 220          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 666          |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 124          |
# |    ep_rew_mean          | -156         |
# | time/                   |              |
# |    fps                  | 2375         |
# |    iterations           | 5            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0023186642 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00322     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 213          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 591          |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 2382         |
# |    iterations           | 6            |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0027710313 |
# |    clip_fraction        | 0.000355     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.00271     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 401          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 650          |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -162        |
# | time/                   |             |
# |    fps                  | 2332        |
# |    iterations           | 7           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.004195702 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.00225    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 171         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 565         |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 154          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 2297         |
# |    iterations           | 8            |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0044725244 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.0006      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 272          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 504          |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | -97.9       |
# | time/                   |             |
# |    fps                  | 2225        |
# |    iterations           | 9           |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005479668 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.000774    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 348         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 433         |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | -61.5       |
# | time/                   |             |
# |    fps                  | 2163        |
# |    iterations           | 10          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.004791072 |
# |    clip_fraction        | 0.0241      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.00279     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 238         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 390         |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | -74.4       |
# | time/                   |             |
# |    fps                  | 2073        |
# |    iterations           | 11          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.004896594 |
# |    clip_fraction        | 0.00262     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.00353     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 151         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 330         |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 1943        |
# |    iterations           | 12          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.004430442 |
# |    clip_fraction        | 0.00382     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.0234      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 80.1        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 309         |
# -----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 333         |
# |    ep_rew_mean          | -27.6       |
# | time/                   |             |
# |    fps                  | 1769        |
# |    iterations           | 13          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.005151448 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.0414      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 111         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 279         |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | -56.9       |
# | time/                   |             |
# |    fps                  | 1669        |
# |    iterations           | 14          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.005413849 |
# |    clip_fraction        | 0.00913     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.0596      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 129         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 223         |
# -----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 430          |
# |    ep_rew_mean          | -43.1        |
# | time/                   |              |
# |    fps                  | 1568         |
# |    iterations           | 15           |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0050154976 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0547       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 108          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 206          |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | -38.4       |
# | time/                   |             |
# |    fps                  | 1477        |
# |    iterations           | 16          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.005374351 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.092       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 118         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 164         |
# -----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 551          |
# |    ep_rew_mean          | -34.1        |
# | time/                   |              |
# |    fps                  | 1388         |
# |    iterations           | 17           |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0057754847 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0921       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 78.9         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 168          |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 660         |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 18          |
# |    time_elapsed         | 449         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.005305488 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 38.7        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 131         |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 0.365        |
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 19           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0014793756 |
# |    clip_fraction        | 0.00478      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.229        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 70.2         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 91           |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 820          |
# |    ep_rew_mean          | -0.99        |
# | time/                   |              |
# |    fps                  | 1167         |
# |    iterations           | 20           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0033264088 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 35.8         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00301     |
# |    value_loss           | 84.4         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 875          |
# |    ep_rew_mean          | -5.42        |
# | time/                   |              |
# |    fps                  | 1112         |
# |    iterations           | 21           |
# |    time_elapsed         | 618          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0048503606 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 35.9         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 84.3         |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 909          |
# |    ep_rew_mean          | 0.693        |
# | time/                   |              |
# |    fps                  | 1065         |
# |    iterations           | 22           |
# |    time_elapsed         | 676          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0046552615 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 18           |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 67.8         |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 927          |
# |    ep_rew_mean          | -17.1        |
# | time/                   |              |
# |    fps                  | 1020         |
# |    iterations           | 23           |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0044873767 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.99        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 20.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 67.7         |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | -34.4        |
# | time/                   |              |
# |    fps                  | 981          |
# |    iterations           | 24           |
# |    time_elapsed         | 801          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0013864363 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.987       |
# |    explained_variance   | 0.0414       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 62.1         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 55           |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -49.1       |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 25          |
# |    time_elapsed         | 866         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.002875752 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0211      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 985          |
# |    ep_rew_mean          | -46          |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 26           |
# |    time_elapsed         | 930          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0038361812 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.0472       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 18           |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 39.4         |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 887         |
# |    iterations           | 27          |
# |    time_elapsed         | 996         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.004658505 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.1        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 31.9        |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 996          |
# |    ep_rew_mean          | -25.3        |
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 28           |
# |    time_elapsed         | 1057         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0021226527 |
# |    clip_fraction        | 0.00715      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 16.5         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 28.4         |
# ------------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | -24.1        |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 29           |
# |    time_elapsed         | 1124         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0035293659 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.992       |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 13.4         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 29.7         |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 981          |
# |    ep_rew_mean          | -20.7        |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 30           |
# |    time_elapsed         | 1185         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0025657178 |
# |    clip_fraction        | 0.00651      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.65         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 17.5         |
# ------------------------------------------
# Early stopping at step 8 due to reaching max kl: 0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | -16.9        |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 31           |
# |    time_elapsed         | 1254         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0044789584 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.987       |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.79         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 46.4         |
# ------------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.01
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.155 MB of 0.155 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval_reward_mean</td><td>▁</td></tr><tr><td>eval_reward_std</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▂▁▂▂▂▂▃▃▄▄▅▅▆▇▇▇▇████████</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▂▃▃▂▁▂▄▄▆▅▄▇▆▆▆▇▇████▇▇▆▆▆▇▇▇▇</td></tr><tr><td>time/fps</td><td>█▅▅▆▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>train/approx_kl</td><td>█▇▆▂▃▅▆▇▆▆▆▇▇▇▇█▇▁▄▆▆▆▁▃▅▆▂▄▃▆</td></tr><tr><td>train/clip_fraction</td><td>▅▃▁▁▁▆▄▄▆▂▂▆▃▆▅▇▆▂▇▄▇▆▂█▄▅▂▄▂▅</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▂▂▃▃▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇██▇▇█▇█▇█</td></tr><tr><td>train/explained_variance</td><td>▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▃▃▅▄▄▄▃▂▁▂▃▅▄█▆</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▇█▃▃▆▃▄▅▄▃▂▂▂▂▂▂▁▂▁▁▁▁▂▁▁▁▁▁▁▁</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▂▅▄▅▄▄▆▂▃▄▃▆▄▄▄▅▇▄▆▃▅█▆▅▄█▅▆▇</td></tr><tr><td>train/value_loss</td><td>█▆▅▄▅▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval_reward_mean</td><td>-83.50977</td></tr><tr><td>eval_reward_std</td><td>27.32187</td></tr><tr><td>global_step</td><td>1015808</td></tr><tr><td>rollout/ep_len_mean</td><td>956.12</td></tr><tr><td>rollout/ep_rew_mean</td><td>-16.932</td></tr><tr><td>time/fps</td><td>809.0</td></tr><tr><td>train/approx_kl</td><td>0.00448</td></tr><tr><td>train/clip_fraction</td><td>0.02142</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-0.98729</td></tr><tr><td>train/explained_variance</td><td>0.31373</td></tr><tr><td>train/learning_rate</td><td>0.0001</td></tr><tr><td>train/loss</td><td>7.79092</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.00155</td></tr><tr><td>train/value_loss</td><td>46.37445</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">blooming-sweep-2</strong>: <a href="https://wandb.ai/arampacha/hf-deep-rl-class/runs/w6sb18k2" target="_blank">https://wandb.ai/arampacha/hf-deep-rl-class/runs/w6sb18k2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20220509_220356-w6sb18k2/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
